# %%
import pandas as pd
import tradingview_indicators as ta

# %%
df = pd.read_csv("BTCUSDT_1d_spot.csv", index_col=0).drop(columns='open_time_ms')
df
# Out:
#                 open      high       low     close
# open_time
# 2017-08-17   4261.48   4485.39   4200.74   4285.08
# 2017-08-18   4285.08   4371.52   3938.77   4108.37
# 2017-08-19   4108.37   4184.69   3850.00   4139.98
# 2017-08-20   4120.98   4211.08   4032.62   4086.29
# 2017-08-21   4069.13   4119.62   3911.79   4016.00
# ...              ...       ...       ...       ...
# 2023-09-02  25805.04  25987.50  25752.47  25869.51
# 2023-09-03  25869.52  26135.00  25800.00  25971.21
# 2023-09-04  25971.21  26108.02  25631.21  25826.02
# 2023-09-05  25826.03  25915.49  25562.62  25792.10
# 2023-09-06  25792.11  26040.00  25372.51  25684.13
#
# [2212 rows x 4 columns]

# %%
source = df["close"].copy()
df["RSI"] = ta.RSI(source, 14)
df["MACD"] = ta.MACD(source, 12, 26, 9).get_histogram
df['EMA'] = ta.ema(source, 14)
df["SMA"] = ta.sma(source, 14)
df["RMA"] = ta.rma(source, 14)
df["TEMA"] = ta.sema(source, 14, 3)

dmi = ta.DMI(df, "close")

df["ADX"] = dmi.adx()[0]
df["DI+"] = dmi.adx()[1]
df["DI-"] = dmi.adx()[2]
df["DI_Delta"] = dmi.di_difference()[0]
df["DI_Ratio"] = dmi.di_difference()[1]
df
# Out:
#                 open      high       low     close        RSI       MACD  \
# open_time
# 2017-08-17   4261.48   4485.39   4200.74   4285.08        NaN        NaN
# 2017-08-18   4285.08   4371.52   3938.77   4108.37        NaN        NaN
# 2017-08-19   4108.37   4184.69   3850.00   4139.98        NaN        NaN
# 2017-08-20   4120.98   4211.08   4032.62   4086.29        NaN        NaN
# 2017-08-21   4069.13   4119.62   3911.79   4016.00        NaN        NaN
# ...              ...       ...       ...       ...        ...        ...
# 2023-09-02  25805.04  25987.50  25752.47  25869.51  36.335241  40.580601
# 2023-09-03  25869.52  26135.00  25800.00  25971.21  37.672239  42.070915
# 2023-09-04  25971.21  26108.02  25631.21  25826.02  36.493947  37.961352
# 2023-09-05  25826.03  25915.49  25562.62  25792.10  36.209008  37.571794
# 2023-09-06  25792.11  26040.00  25372.51  25684.13  35.265145  34.722954
#
#                      EMA           SMA           RMA          TEMA        ADX  \
# ...
